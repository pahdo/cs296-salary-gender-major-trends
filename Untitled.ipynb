# %% [markdown]
# Our salary dataset comes from this source:
# https://www.kaggle.com/mchirico/d/fivethirtyeight/fivethirtyeight/college-majors/output
#
# Our majors and enrollment dataset comes from Activity 2

# %%
import pandas as pd

# %%
demographics = pd.read_csv('uiuc_demographics_2005_15.csv')

# %%
demographics
# Out:
#         Fall  Term Code College  Dept.  Degree  Major Code  \
# 0     2015.0   120158.0     KP   227.0     BS       5163.0
# 1     2015.0   120158.0     KP   227.0     BS       5163.0
# 2     2015.0   120158.0     KP   227.0  MENGR       1211.0
# 3     2015.0   120158.0     KP   227.0     BS       5163.0
# 4     2015.0   120158.0     KP   227.0     MS       5163.0
# 5     2015.0   120158.0     KP   227.0    PHD       5163.0
# 6     2015.0   120158.0     KP   227.0   NDEG         67.0
# 7     2015.0   120158.0     KM   230.0    MBA       9875.0
# 8     2015.0   120158.0     KM   230.0    MBA       9875.0
# 9     2015.0   120158.0     KM   230.0    MBA       9875.0
# 10    2015.0   120158.0     KT   238.0    PHD        279.0
# 11    2015.0   120158.0     KT   238.0    PHD       5202.0
# 12    2015.0   120158.0     KV   241.0  BALAS        340.0
# 13    2015.0   120158.0     KV   241.0  BALAS        340.0
# 14    2015.0   120158.0     KV   241.0  BSLAS       5348.0
# ...

# %%
salaries = pd.read_csv('recent-grads.csv')

# %%
salaries
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
demographics['Degree'].unique()
validdeg = ['BS ', 'BALAS ', 'BSLAS ',
       'BMUS ', 'BME ',
        'BA ', 'AD ',  'BFA ', 
       'BLA ',  'BSJ ',
       'BSAG ', 'BSW ',  
      'BSLA ']

# %%
df = demographics.loc[demographics['Degree'].isin(validdeg)]
df
df.to_csv('bslike.csv',index=False)
